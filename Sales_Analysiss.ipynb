# %%
import pandas as pd
import os
import plotly.express as px
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
files=[file for file in os.listdir(r'C:\Users\DEVEN\Desktop\FINALE\PYTHONN\PROJECT\MONTHLY SALES')]

# %%
files
# Out:
# ['Sales_April_2019.csv',
#  'Sales_August_2019.csv',
#  'Sales_December_2019.csv',
#  'Sales_February_2019.csv',
#  'Sales_January_2019.csv',
#  'Sales_July_2019.csv',
#  'Sales_June_2019.csv',
#  'Sales_March_2019.csv',
#  'Sales_May_2019.csv',
#  'Sales_November_2019.csv',
#  'Sales_October_2019.csv',
#  'Sales_September_2019.csv']

# %%
data=pd.DataFrame()

# %%
for file in files:
    df1=pd.read_csv("C:/Users/DEVEN/Desktop/FINALE/PYTHONN/PROJECT/MONTHLY SALES/" +file)
    data=pd.concat([data,df1],ignore_index=True)

# %%
data
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 1           NaN                         NaN              NaN        NaN
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address
# 0       04/19/19 08:46             917 1st St, Dallas, TX 75001
# 1                  NaN                                      NaN
# 2       04/07/19 22:30        682 Chestnut St, Boston, MA 02215
# 3       04/12/19 14:38     669 Spruce St, Los Angeles, CA 90001
# 4       04/12/19 14:38     669 Spruce St, Los Angeles, CA 90001
# ...                ...                                      ...
# 186845  09/17/19 20:56   840 Highland St, Los Angeles, CA 90001
# 186846  09/01/19 16:00  216 Dogwood St, San Francisco, CA 94016
# 186847  09/23/19 07:39     220 12th St, San Francisco, CA 94016
# 186848  09/19/19 17:30   511 Forest St, San Francisco, CA 94016
# 186849  09/30/19 00:18   250 Meadow St, San Francisco, CA 94016
#
# [186850 rows x 6 columns]

# %%
data .isna().sum()
# Out:
# Order ID            545
# Product             545
# Quantity Ordered    545
# Price Each          545
# Order Date          545
# Purchase Address    545
# dtype: int64

# %%
data=data.dropna()  # dropped nulls

# %%
data.info()  # all are object type
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 186850 entries, 0 to 186849
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          186305 non-null  object
#  1   Product           186305 non-null  object
#  2   Quantity Ordered  186305 non-null  object
#  3   Price Each        186305 non-null  object
#  4   Order Date        186305 non-null  object
#  5   Purchase Address  186305 non-null  object
# dtypes: object(6)
# memory usage: 8.6+ MB

# %%
data.duplicated().sum()
# Out:
# 1162

# %%
data.shape
# Out:
# (186850, 6)

# %%
data.head(2)
# Out:
#   Order ID               Product Quantity Ordered Price Each      Order Date  \
# 0   176558  USB-C Charging Cable                2      11.95  04/19/19 08:46
# 1      NaN                   NaN              NaN        NaN             NaN
#
#                Purchase Address
# 0  917 1st St, Dallas, TX 75001
# 1                           NaN

# %% [markdown]
# ### Cleaning

# %% [raw]
# >Into numeric          : Quantity Ordered,
#                          Price Each
#
# >Date                  : Order Date
#
# >Split                 : Purchase Address
#
# > create new columns   :  month,
#                           hour,
#                           Sales,
#                           city
#                           State
#
#
#
#
# >Drop                  :  duplicates,
#                           NaN,
#                           Nat,
#                           Null,
#                           unnesessary columns
#
# >Reset_index
#
# >save cleaned dataset on Local

# %%
data.columns
# Out:
# Index(['Order ID', 'Product', 'Quantity Ordered', 'Price Each', 'Order Date',
#        'Purchase Address'],
#       dtype='object')

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
data['Quantity Ordered']=pd.to_numeric(data['Quantity Ordered'],errors='coerce')
data['Price Each']=pd.to_numeric(data['Price Each'],errors='coerce')
data['Sales']=(data['Quantity Ordered'])*(data['Price Each'])

# %%
data.head(2)
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable               2.0       11.95
# 2   176559  Bose SoundSport Headphones               1.0       99.99
#
#        Order Date                   Purchase Address  Sales
# 0  04/19/19 08:46       917 1st St, Dallas, TX 75001  23.90
# 2  04/07/19 22:30  682 Chestnut St, Boston, MA 02215  99.99

# %%
data[['City','Zip']]=data['Purchase Address'].str.split(',',expand=True).iloc[:,1:]
data['State']=data['Zip'].str[1:3]
data['Zip']=data['Zip'].str[3:]

# %%
data.head(2)
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable               2.0       11.95
# 2   176559  Bose SoundSport Headphones               1.0       99.99
#
#        Order Date                   Purchase Address  Sales     City     Zip  \
# 0  04/19/19 08:46       917 1st St, Dallas, TX 75001  23.90   Dallas   75001
# 2  04/07/19 22:30  682 Chestnut St, Boston, MA 02215  99.99   Boston   02215
#
#   State
# 0    TX
# 2    MA

# %%
data['Order Date']=pd.to_datetime(data['Order Date'],errors='coerce')
data['Month']=pd.to_datetime(data['Order Date'],errors='coerce').dt.month
data['Hour']=pd.to_datetime(data['Order Date'],errors='coerce').dt.hour

# %%
data.head(2)
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable               2.0       11.95
# 1   176559  Bose SoundSport Headphones               1.0       99.99
#
#            Order Date  Sales     City     Zip State  Month  Hour
# 0 2019-04-19 08:46:00  23.90   Dallas   75001    TX      4     8
# 1 2019-04-07 22:30:00  99.99   Boston   02215    MA      4    22

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 186305 entries, 0 to 186849
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          186305 non-null  object
#  1   Product           186305 non-null  object
#  2   Quantity Ordered  185950 non-null  float64
#  3   Price Each        185950 non-null  float64
#  4   Order Date        185950 non-null  datetime64[ns]
#  5   Purchase Address  186305 non-null  object
#  6   Sales             185950 non-null  float64
#  7   City              185950 non-null  object
#  8   Zip               185950 non-null  object
#  9   State             185950 non-null  object
#  10  Month             185950 non-null  object
#  11  Hour              185950 non-null  float64
# dtypes: datetime64[ns](1), float64(4), object(7)
# memory usage: 18.5+ MB

# %%
data.describe()
# Out:
#        Quantity Ordered     Price Each          Sales           Hour
# count     185950.000000  185950.000000  185950.000000  185950.000000
# mean           1.124383     184.399735     185.490917      14.413305
# std            0.442793     332.731330     332.919771       5.423416
# min            1.000000       2.990000       2.990000       0.000000
# 25%            1.000000      11.950000      11.950000      11.000000
# 50%            1.000000      14.950000      14.950000      15.000000
# 75%            1.000000     150.000000     150.000000      19.000000
# max            9.000000    1700.000000    3400.000000      23.000000

# %%
data.shape
# Out:
# (186305, 12)

# %%
data.isna().sum()
# Out:
# Order ID            0
# Product             0
# Quantity Ordered    0
# Price Each          0
# Order Date          0
# Purchase Address    0
# Sales               0
# City                0
# Zip                 0
# State               0
# Month               0
# Hour                0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 264

# %%
data[data['Order ID']=='176585']
# Out:
#    Order ID                     Product  Quantity Ordered  Price Each  \
# 30   176585  Bose SoundSport Headphones               1.0       99.99
# 31   176585  Bose SoundSport Headphones               1.0       99.99
#
#             Order Date                   Purchase Address  Sales     City  \
# 30 2019-04-07 11:31:00  823 Highland St, Boston, MA 02215  99.99   Boston
# 31 2019-04-07 11:31:00  823 Highland St, Boston, MA 02215  99.99   Boston
#
#        Zip State  Month  Hour
# 30   02215    MA  April  11.0
# 31   02215    MA  April  11.0

# %%
data=data.dropna()  # It will dropp NaN,Nat,None
data=data.drop_duplicates()
#data=data.drop(columns='Purchase Address')

# %%
data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable               2.0       11.95
# 1   176559  Bose SoundSport Headphones               1.0       99.99
# 2   176560                Google Phone               1.0      600.00
# 3   176560            Wired Headphones               1.0       11.99
# 4   176561            Wired Headphones               1.0       11.99
#
#            Order Date   Sales          City     Zip State  Month  Hour
# 0 2019-04-19 08:46:00   23.90        Dallas   75001    TX  April   8.0
# 1 2019-04-07 22:30:00   99.99        Boston   02215    MA  April  22.0
# 2 2019-04-12 14:38:00  600.00   Los Angeles   90001    CA  April  14.0
# 3 2019-04-12 14:38:00   11.99   Los Angeles   90001    CA  April  14.0
# 4 2019-04-30 09:27:00   11.99   Los Angeles   90001    CA  April   9.0

# %%
data.shape
# Out:
# (185686, 11)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 185686 entries, 0 to 186849
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185686 non-null  object
#  1   Product           185686 non-null  object
#  2   Quantity Ordered  185686 non-null  float64
#  3   Price Each        185686 non-null  float64
#  4   Order Date        185686 non-null  datetime64[ns]
#  5   Sales             185686 non-null  float64
#  6   City              185686 non-null  object
#  7   Zip               185686 non-null  object
#  8   State             185686 non-null  object
#  9   Month             185686 non-null  object
#  10  Hour              185686 non-null  float64
# dtypes: datetime64[ns](1), float64(4), object(6)
# memory usage: 17.0+ MB

# %%
data=data[data['Order Date'].dt.year==2019]  #very few data for 2020 ,hence kept only 2020 
data=data.reset_index(drop=True)

# %%
data.head(50)
# Out:
#    Order ID                     Product  Quantity Ordered  Price Each  \
# 0    176558        USB-C Charging Cable               2.0       11.95
# 1    176559  Bose SoundSport Headphones               1.0       99.99
# 2    176560                Google Phone               1.0      600.00
# 3    176560            Wired Headphones               1.0       11.99
# 4    176561            Wired Headphones               1.0       11.99
# 5    176562        USB-C Charging Cable               1.0       11.95
# 6    176563  Bose SoundSport Headphones               1.0       99.99
# 7    176564        USB-C Charging Cable               1.0       11.95
# 8    176565          Macbook Pro Laptop               1.0     1700.00
# 9    176566            Wired Headphones               1.0       11.99
# 10   176567                Google Phone               1.0      600.00
# 11   176568    Lightning Charging Cable               1.0       14.95
# 12   176569      27in 4K Gaming Monitor               1.0      389.99
# 13   176570       AA Batteries (4-pack)               1.0        3.84
# 14   176571    Lightning Charging Cable               1.0       14.95
# 15   176572    Apple Airpods Headphones               1.0      150.00
# 16   176573        USB-C Charging Cable               1.0       11.95
# 17   176574                Google Phone               1.0      600.00
# 18   176574        USB-C Charging Cable               1.0       11.95
# 19   176575      AAA Batteries (4-pack)               1.0        2.99
# 20   176576    Apple Airpods Headphones               1.0      150.00
# 21   176577    Apple Airpods Headphones               1.0      150.00
# 22   176578    Apple Airpods Headphones               1.0      150.00
# 23   176579       AA Batteries (4-pack)               1.0        3.84
# 24   176580        USB-C Charging Cable               1.0       11.95
# 25   176581                      iPhone               1.0      700.00
# 26   176582  Bose SoundSport Headphones               1.0       99.99
# 27   176583      AAA Batteries (4-pack)               2.0        2.99
# 28   176584               Flatscreen TV               1.0      300.00
# 29   176585  Bose SoundSport Headphones               1.0       99.99
# 30   176586      AAA Batteries (4-pack)               2.0        2.99
# 31   176586                Google Phone               1.0      600.00
# 32   176587            27in FHD Monitor               1.0      149.99
# 33   176588                20in Monitor               1.0      109.99
# 34   176589    Lightning Charging Cable               1.0       14.95
# 35   176590                Google Phone               1.0      600.00
# 36   176591    Apple Airpods Headphones               1.0      150.00
# 37   176592        USB-C Charging Cable               1.0       11.95
# 38   176593    Lightning Charging Cable               2.0       14.95
# 39   176594            Wired Headphones               1.0       11.99
# 40   176595            Wired Headphones               3.0       11.99
# 41   176596    Apple Airpods Headphones               1.0      150.00
# 42   176597        USB-C Charging Cable               1.0       11.95
# 43   176598      AAA Batteries (4-pack)               2.0        2.99
# 44   176599    Lightning Charging Cable               1.0       14.95
# 45   176600      27in 4K Gaming Monitor               1.0      389.99
# 46   176601        USB-C Charging Cable               1.0       11.95
# 47   176602    Lightning Charging Cable               1.0       14.95
# 48   176603        USB-C Charging Cable               1.0       11.95
# 49   176604        USB-C Charging Cable               1.0       11.95
#
#             Order Date    Sales            City     Zip State  Month  Hour
# 0  2019-04-19 08:46:00    23.90          Dallas   75001    TX      4     8
# 1  2019-04-07 22:30:00    99.99          Boston   02215    MA      4    22
# 2  2019-04-12 14:38:00   600.00     Los Angeles   90001    CA      4    14
# 3  2019-04-12 14:38:00    11.99     Los Angeles   90001    CA      4    14
# 4  2019-04-30 09:27:00    11.99     Los Angeles   90001    CA      4     9
# 5  2019-04-29 13:03:00    11.95   San Francisco   94016    CA      4    13
# 6  2019-04-02 07:46:00    99.99         Seattle   98101    WA      4     7
# 7  2019-04-12 10:58:00    11.95         Atlanta   30301    GA      4    10
# 8  2019-04-24 10:38:00  1700.00   San Francisco   94016    CA      4    10
# 9  2019-04-08 14:05:00    11.99          Boston   02215    MA      4    14
# 10 2019-04-18 17:18:00   600.00     Los Angeles   90001    CA      4    17
# 11 2019-04-15 12:18:00    14.95         Seattle   98101    WA      4    12
# 12 2019-04-16 19:23:00   389.99          Dallas   75001    TX      4    19
# 13 2019-04-22 15:09:00     3.84          Dallas   75001    TX      4    15
# 14 2019-04-19 14:29:00    14.95         Atlanta   30301    GA      4    14
# 15 2019-04-04 20:30:00   150.00   New York City   10001    NY      4    20
# 16 2019-04-27 18:41:00    11.95   San Francisco   94016    CA      4    18
# 17 2019-04-03 19:42:00   600.00     Los Angeles   90001    CA      4    19
# 18 2019-04-03 19:42:00    11.95     Los Angeles   90001    CA      4    19
# 19 2019-04-27 00:30:00     2.99   New York City   10001    NY      4     0
# 20 2019-04-28 11:42:00   150.00     Los Angeles   90001    CA      4    11
# 21 2019-04-04 19:25:00   150.00          Dallas   75001    TX      4    19
# 22 2019-04-09 23:35:00   150.00          Boston   02215    MA      4    23
# 23 2019-04-11 10:23:00     3.84   New York City   10001    NY      4    10
# 24 2019-04-05 00:35:00    11.95     Los Angeles   90001    CA      4     0
# 25 2019-04-09 21:38:00   700.00          Boston   02215    MA      4    21
# 26 2019-04-27 12:20:00    99.99         Atlanta   30301    GA      4    12
# 27 2019-04-20 12:00:00     5.98        Portland   97035    OR      4    12
# 28 2019-04-24 20:39:00   300.00   San Francisco   94016    CA      4    20
# 29 2019-04-07 11:31:00    99.99          Boston   02215    MA      4    11
# 30 2019-04-10 17:00:00     5.98   San Francisco   94016    CA      4    17
# 31 2019-04-10 17:00:00   600.00   San Francisco   94016    CA      4    17
# 32 2019-04-29 19:38:00   149.99     Los Angeles   90001    CA      4    19
# 33 2019-04-02 04:00:00   109.99         Seattle   98101    WA      4     4
# 34 2019-04-04 12:23:00    14.95         Atlanta   30301    GA      4    12
# 35 2019-04-11 11:46:00   600.00   New York City   10001    NY      4    11
# 36 2019-04-21 07:21:00   150.00          Austin   73301    TX      4     7
# 37 2019-04-27 13:04:00    11.95     Los Angeles   90001    CA      4    13
# 38 2019-04-15 13:45:00    29.90        Portland   97035    OR      4    13
# 39 2019-04-17 23:04:00    11.99   San Francisco   94016    CA      4    23
# 40 2019-04-02 09:11:00    35.97     Los Angeles   90001    CA      4     9
# 41 2019-04-27 20:11:00   150.00          Dallas   75001    TX      4    20
# 42 2019-04-19 13:39:00    11.95   San Francisco   94016    CA      4    13
# 43 2019-04-21 20:33:00     5.98   San Francisco   94016    CA      4    20
# 44 2019-04-11 15:25:00    14.95   New York City   10001    NY      4    15
# 45 2019-04-30 15:54:00   389.99          Boston   02215    MA      4    15
# 46 2019-04-02 22:32:00    11.95     Los Angeles   90001    CA      4    22
# 47 2019-04-30 09:39:00    14.95          Dallas   75001    TX      4     9
# 48 2019-04-01 07:46:00    11.95   San Francisco   94016    CA      4     7
# 49 2019-04-02 10:57:00    11.95   San Francisco   94016    CA      4    10

# %%
data.to_csv(r'C:\Users\DEVEN\Desktop\FINALE\PYTHONN\PROJECT\Final Submission\Cleaned_Sales_Dataset.csv')

# %% [markdown]
# ### Question 1: What was the best month for sales? How much was earned that month?

# %%
Monthly_Sales=data.groupby('Month')['Sales'].sum().reset_index()
Monthly_Sales['Month']=pd.to_datetime(Monthly_Sales['Month'], format='%m').dt.strftime('%B')

# %%
data.groupby('Month')['Sales'].sum().reset_index()
# Out:
#     Month       Sales
# 0       1  1812742.87
# 1       2  2200078.08
# 2       3  2804973.35
# 3       4  3389217.98
# 4       5  3150616.23
# 5       6  2576280.15
# 6       7  2646461.32
# 7       8  2241083.37
# 8       9  2094465.69
# 9      10  3734777.86
# 10     11  3197875.05
# 11     12  4608295.70

# %%
plt.plot(Monthly_Sales['Month'],Monthly_Sales['Sales'],marker='v',linewidth=2,color='g')
plt.xlabel('Months',color='g')
plt.ylabel('Sales in Million($)')
plt.title('Monthly Sales')
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# December was the Best Month For Sale ,Sales=4608295.70

# %% [markdown]
# ### Question 2: Which city sold the most product?

# %%
city=data.groupby('City')['Sales'].sum().reset_index().sort_values(by='Sales',ascending=False)
Qnty=data.groupby('City')['Quantity Ordered'].sum().reset_index().sort_values(by='Quantity Ordered',ascending=False)

# %%
plt.figure(figsize=(10,4))

plt.subplot(1,2,1)                           # made subplot one row two column and assign this plot at 1st position

plt.bar(city['City'],city['Sales'],color='r')
plt.xlabel('Cities')
plt.ylabel('Sales in Million($)')
plt.title('Best City Sales-Wise')
plt.xticks(rotation=90)


plt.subplot(1,2,2)   

# assign this plot at 1st position
plt.bar(Qnty['City'],Qnty['Quantity Ordered'],color='g')
plt.xlabel('Cities')
plt.ylabel('Quantity')
plt.title('Best City Quantity-Wise')
plt.xticks(rotation=90)

plt.subplots_adjust(wspace=0.5) # space between two subplots

plt.show()

# %%
data
# Out:
#         Order ID                     Product  Quantity Ordered  Price Each  \
# 0         176558        USB-C Charging Cable               2.0       11.95
# 1         176559  Bose SoundSport Headphones               1.0       99.99
# 2         176560                Google Phone               1.0      600.00
# 3         176560            Wired Headphones               1.0       11.99
# 4         176561            Wired Headphones               1.0       11.99
# ...          ...                         ...               ...         ...
# 185647    259353      AAA Batteries (4-pack)               3.0        2.99
# 185648    259354                      iPhone               1.0      700.00
# 185649    259355                      iPhone               1.0      700.00
# 185650    259356      34in Ultrawide Monitor               1.0      379.99
# 185651    259357        USB-C Charging Cable               1.0       11.95
#
#                  Order Date   Sales            City    Zip State  Month  Hour
# 0       2019-04-19 08:46:00   23.90          Dallas  75001    TX      4     8
# 1       2019-04-07 22:30:00   99.99          Boston   2215    MA      4    22
# 2       2019-04-12 14:38:00  600.00     Los Angeles  90001    CA      4    14
# 3       2019-04-12 14:38:00   11.99     Los Angeles  90001    CA      4    14
# 4       2019-04-30 09:27:00   11.99     Los Angeles  90001    CA      4     9
# ...                     ...     ...             ...    ...   ...    ...   ...
# 185647  2019-09-17 20:56:00    8.97     Los Angeles  90001    CA      9    20
# 185648  2019-09-01 16:00:00  700.00   San Francisco  94016    CA      9    16
# 185649  2019-09-23 07:39:00  700.00   San Francisco  94016    CA      9     7
# 185650  2019-09-19 17:30:00  379.99   San Francisco  94016    CA      9    17
# 185651  2019-09-30 00:18:00   11.95   San Francisco  94016    CA      9     0
#
# [185652 rows x 11 columns]

# %% [markdown]
# ### Question 3: At what time should we display advertisements to maximize the likelihood of a customer buying a product?

# %%
Advertise=data.pivot_table(index='Hour',values='Product',aggfunc='count').reset_index()
x=np.arange(0,24)

# %%
plt.figure(figsize=(7.5, 4))
sns.lineplot(x='Hour', y='Product', data=Advertise, marker='o', color='#363c54')

plt.xticks(np.arange(0, 24))
plt.title("Product Sales by Hour")
plt.xlabel("Hour")
plt.ylabel("Number of Products Sold")

plt.show()

# %% [raw]
# From 10AM till 9PM

# %% [markdown]
# ### Question 4: What products are most often sold together?

# %%
df =data[data['Order ID'].duplicated(keep=False)] # Filter the DataFrame 'df' to get only the rows where 'Order ID' is duplicated

df['Combos'] = df.groupby('Order ID')['Product'].transform(lambda x:','.join(x)) 
                # Create a new column 'Combos' in 'df'
                # Group the filtered DataFrame by 'Order ID' and then use the transform function
                # The lambda function joins all products for the same 'Order ID' into a single string, separated by commas.

df=df[['Order ID','Combos']].drop_duplicates()
                # Keep only the 'Order ID' and 'Combos' columns, and remove any duplicate rows
df
# Out:
#         Order ID                                         Combos
# 2         176560                  Google Phone,Wired Headphones
# 17        176574              Google Phone,USB-C Charging Cable
# 30        176586            AAA Batteries (4-pack),Google Phone
# 117       176672  Lightning Charging Cable,USB-C Charging Cable
# 127       176681       Apple Airpods Headphones,ThinkPad Laptop
# ...          ...                                            ...
# 185566    259277                        iPhone,Wired Headphones
# 185587    259297                iPhone,Lightning Charging Cable
# 185594    259303   34in Ultrawide Monitor,AA Batteries (4-pack)
# 185606    259314        Wired Headphones,AAA Batteries (4-pack)
# 185643    259350              Google Phone,USB-C Charging Cable
#
# [6876 rows x 2 columns]

# %%
from collections import Counter
from itertools import combinations

# %%
cnt = Counter()            # an empty Counter to count product pairs.     

for row in df['Combos']:    # Go through each row in the 'Combos' column.  
    row_list = row.split(',')   # Split the row into a list of products.
    cnt.update(Counter(combinations(row_list,2)))     # Find all pairs of products in the list.

# %%
cnt
# Out:
# Counter({('Google Phone', 'Wired Headphones'): 413,
#          ('Google Phone', 'USB-C Charging Cable'): 985,
#          ('AAA Batteries (4-pack)', 'Google Phone'): 11,
#          ('Lightning Charging Cable', 'USB-C Charging Cable'): 58,
#          ('Apple Airpods Headphones', 'ThinkPad Laptop'): 9,
#          ('Bose SoundSport Headphones', 'AAA Batteries (4-pack)'): 37,
#          ('34in Ultrawide Monitor', 'Google Phone'): 2,
#          ('iPhone', 'Lightning Charging Cable'): 1001,
#          ('Google Phone', 'Bose SoundSport Headphones'): 220,
#          ('Bose SoundSport Headphones', 'Wired Headphones'): 53,
#          ('AAA Batteries (4-pack)', '27in FHD Monitor'): 22,
#          ('USB-C Charging Cable', 'AAA Batteries (4-pack)'): 45,
#          ('iPhone', 'Wired Headphones'): 447,
#          ('iPhone', '27in 4K Gaming Monitor'): 6,
#          ('ThinkPad Laptop', 'AAA Batteries (4-pack)'): 16,
#          ('iPhone', 'Apple Airpods Headphones'): 359,
#          ('iPhone', 'AAA Batteries (4-pack)'): 17,
#          ('Apple Airpods Headphones', 'AAA Batteries (4-pack)'): 48,
#          ('Wired Headphones', 'Apple Airpods Headphones'): 31,
#          ('Macbook Pro Laptop', 'ThinkPad Laptop'): 3,
#          ('AA Batteries (4-pack)', 'Flatscreen TV'): 13,
#          ('Vareebadd Phone', 'USB-C Charging Cable'): 361,
#          ('USB-C Charging Cable', 'Lightning Charging Cable'): 42,
#          ('Google Phone', 'AA Batteries (4-pack)'): 14,
#          ('AA Batteries (4-pack)', 'AAA Batteries (4-pack)'): 48,
#          ('Bose SoundSport Headphones', 'AA Batteries (4-pack)'): 27,
#          ('20in Monitor', 'Apple Airpods Headphones'): 7,
#          ('USB-C Charging Cable', 'Bose SoundSport Headphones'): 77,
#          ('27in FHD Monitor', 'AAA Batteries (4-pack)'): 21,
#          ('Apple Airpods Headphones', '27in 4K Gaming Monitor'): 12,
#          ('ThinkPad Laptop', 'Google Phone'): 3,
#          ('Wired Headphones', 'Google Phone'): 9,
#          ('Apple Airpods Headphones', 'Google Phone'): 14,
#          ('AAA Batteries (4-pack)', 'Macbook Pro Laptop'): 11,
#          ('Lightning Charging Cable', '27in 4K Gaming Monitor'): 18,
#          ('USB-C Charging Cable', 'Wired Headphones'): 159,
#          ('Apple Airpods Headphones', 'Lightning Charging Cable'): 35,
#          ('AA Batteries (4-pack)', 'Apple Airpods Headphones'): 41,
#          ('34in Ultrawide Monitor', 'USB-C Charging Cable'): 15,
#          ('AAA Batteries (4-pack)', 'Wired Headphones'): 43,
#          ('Lightning Charging Cable', 'AA Batteries (4-pack)'): 55,
#          ('AA Batteries (4-pack)', 'Macbook Pro Laptop'): 8,
#          ('Vareebadd Phone', 'Wired Headphones'): 143,
#          ('Flatscreen TV', 'Lightning Charging Cable'): 10,
#          ('Wired Headphones', 'ThinkPad Laptop'): 10,
#          ('Bose SoundSport Headphones', 'USB-C Charging Cable'): 25,
#          ('USB-C Charging Cable', '20in Monitor'): 10,
#          ('AAA Batteries (4-pack)', 'AA Batteries (4-pack)'): 39,
#          ('AA Batteries (4-pack)', 'Bose SoundSport Headphones'): 28,
#          ('USB-C Charging Cable', '27in 4K Gaming Monitor'): 11,
#          ('27in 4K Gaming Monitor', 'Bose SoundSport Headphones'): 9,
#          ('Lightning Charging Cable', 'AAA Batteries (4-pack)'): 36,
#          ('34in Ultrawide Monitor', 'Macbook Pro Laptop'): 3,
#          ('Wired Headphones', 'USB-C Charging Cable'): 44,
#          ('Wired Headphones', 'AA Batteries (4-pack)'): 39,
#          ('Macbook Pro Laptop', 'Apple Airpods Headphones'): 7,
#          ('USB-C Charging Cable', 'AA Batteries (4-pack)'): 38,
#          ('Macbook Pro Laptop', '20in Monitor'): 2,
#          ('Vareebadd Phone', 'Bose SoundSport Headphones'): 80,
#          ('Wired Headphones', 'Flatscreen TV'): 7,
#          ('USB-C Charging Cable', '27in FHD Monitor'): 31,
#          ('20in Monitor', 'Bose SoundSport Headphones'): 9,
#          ('Flatscreen TV', 'AA Batteries (4-pack)'): 8,
#          ('USB-C Charging Cable', 'ThinkPad Laptop'): 11,
#          ('USB-C Charging Cable', 'iPhone'): 14,
#          ('AA Batteries (4-pack)', 'Wired Headphones'): 44,
#          ('27in FHD Monitor', 'AA Batteries (4-pack)'): 15,
#          ('Lightning Charging Cable', 'Google Phone'): 16,
#          ('Bose SoundSport Headphones', 'Lightning Charging Cable'): 32,
#          ('Apple Airpods Headphones', 'USB-C Charging Cable'): 29,
#          ('Wired Headphones', 'iPhone'): 15,
#          ('27in 4K Gaming Monitor', 'Apple Airpods Headphones'): 10,
#          ('27in 4K Gaming Monitor', 'Vareebadd Phone'): 1,
#          ('AA Batteries (4-pack)', 'Lightning Charging Cable'): 51,
#          ('Apple Airpods Headphones', '27in FHD Monitor'): 12,
#          ('AAA Batteries (4-pack)', '27in 4K Gaming Monitor'): 15,
#          ('Lightning Charging Cable', 'Wired Headphones'): 92,
#          ('Lightning Charging Cable', 'LG Dryer'): 2,
#          ('Apple Airpods Headphones', 'Bose SoundSport Headphones'): 32,
#          ('Macbook Pro Laptop', '34in Ultrawide Monitor'): 4,
#          ('AA Batteries (4-pack)', 'USB-C Charging Cable'): 37,
#          ('AAA Batteries (4-pack)', 'USB-C Charging Cable'): 50,
#          ('iPhone', 'Vareebadd Phone'): 4,
#          ('Lightning Charging Cable', 'Vareebadd Phone'): 3,
#          ('iPhone', 'USB-C Charging Cable'): 15,
#          ('Apple Airpods Headphones', '34in Ultrawide Monitor'): 6,
#          ('AAA Batteries (4-pack)', 'Bose SoundSport Headphones'): 20,
#          ('Wired Headphones', 'Lightning Charging Cable'): 37,
#          ('Apple Airpods Headphones', 'Wired Headphones'): 69,
#          ('34in Ultrawide Monitor', 'Wired Headphones'): 11,
#          ('20in Monitor', 'Lightning Charging Cable'): 11,
#          ('Bose SoundSport Headphones', 'ThinkPad Laptop'): 4,
#          ('27in FHD Monitor', 'Bose SoundSport Headphones'): 12,
#          ('20in Monitor', 'Macbook Pro Laptop'): 4,
#          ('Bose SoundSport Headphones', '27in FHD Monitor'): 14,
#          ('Macbook Pro Laptop', 'AA Batteries (4-pack)'): 9,
#          ('ThinkPad Laptop', 'USB-C Charging Cable'): 9,
#          ('Apple Airpods Headphones', 'AA Batteries (4-pack)'): 29,
#          ('Lightning Charging Cable', 'Apple Airpods Headphones'): 81,
#          ('iPhone', '34in Ultrawide Monitor'): 6,
#          ('20in Monitor', 'USB-C Charging Cable'): 15,
#          ('AA Batteries (4-pack)', '27in FHD Monitor'): 11,
#          ('ThinkPad Laptop', 'Bose SoundSport Headphones'): 9,
#          ('iPhone', 'Bose SoundSport Headphones'): 5,
#          ('Wired Headphones', '20in Monitor'): 7,
#          ('USB-C Charging Cable', 'Apple Airpods Headphones'): 34,
#          ('Macbook Pro Laptop', 'Wired Headphones'): 7,
#          ('Vareebadd Phone', 'Apple Airpods Headphones'): 6,
#          ('Vareebadd Phone', '34in Ultrawide Monitor'): 4,
#          ('Vareebadd Phone', 'AA Batteries (4-pack)'): 9,
#          ('27in FHD Monitor', 'USB-C Charging Cable'): 12,
#          ('USB-C Charging Cable', 'Vareebadd Phone'): 7,
#          ('AA Batteries (4-pack)', 'iPhone'): 18,
#          ('AAA Batteries (4-pack)', 'AAA Batteries (4-pack)'): 19,
#          ('AA Batteries (4-pack)', '34in Ultrawide Monitor'): 13,
#          ('Bose SoundSport Headphones', '34in Ultrawide Monitor'): 11,
#          ('Lightning Charging Cable', '20in Monitor'): 15,
#          ('Google Phone', 'Lightning Charging Cable'): 12,
#          ('34in Ultrawide Monitor', 'AA Batteries (4-pack)'): 19,
#          ('Flatscreen TV', '27in 4K Gaming Monitor'): 2,
#          ('USB-C Charging Cable', 'Flatscreen TV'): 10,
#          ('Google Phone', '27in FHD Monitor'): 7,
#          ('27in FHD Monitor', 'Wired Headphones'): 10,
#          ('ThinkPad Laptop', 'Macbook Pro Laptop'): 2,
#          ('Apple Airpods Headphones', 'Flatscreen TV'): 8,
#          ('ThinkPad Laptop', 'AA Batteries (4-pack)'): 8,
#          ('27in FHD Monitor', 'iPhone'): 1,
#          ('27in 4K Gaming Monitor', '34in Ultrawide Monitor'): 6,
#          ('Apple Airpods Headphones', 'Macbook Pro Laptop'): 12,
#          ('USB-C Charging Cable', 'Macbook Pro Laptop'): 9,
#          ('ThinkPad Laptop', 'Lightning Charging Cable'): 11,
#          ('AA Batteries (4-pack)', 'AA Batteries (4-pack)'): 16,
#          ('Macbook Pro Laptop', 'AAA Batteries (4-pack)'): 7,
#          ('27in FHD Monitor', 'Lightning Charging Cable'): 18,
#          ('AA Batteries (4-pack)', '27in 4K Gaming Monitor'): 14,
#          ('Google Phone', 'AAA Batteries (4-pack)'): 11,
#          ('Flatscreen TV', 'Wired Headphones'): 4,
#          ('USB-C Charging Cable', '34in Ultrawide Monitor'): 11,
#          ('Flatscreen TV', '27in FHD Monitor'): 4,
#          ('Lightning Charging Cable', 'Bose SoundSport Headphones'): 39,
#          ('AA Batteries (4-pack)', '20in Monitor'): 10,
#          ('34in Ultrawide Monitor', 'iPhone'): 7,
#          ('Vareebadd Phone', 'Lightning Charging Cable'): 1,
#          ('Lightning Charging Cable', '27in FHD Monitor'): 18,
#          ('AAA Batteries (4-pack)', 'Lightning Charging Cable'): 44,
#          ('AAA Batteries (4-pack)', '34in Ultrawide Monitor'): 13,
#          ('Google Phone', 'ThinkPad Laptop'): 3,
#          ('AAA Batteries (4-pack)', 'iPhone'): 14,
#          ('27in 4K Gaming Monitor', 'Macbook Pro Laptop'): 6,
#          ('AAA Batteries (4-pack)', 'Flatscreen TV'): 10,
#          ('27in 4K Gaming Monitor', 'USB-C Charging Cable'): 12,
#          ('LG Dryer', 'AA Batteries (4-pack)'): 4,
#          ('Flatscreen TV', 'USB-C Charging Cable'): 7,
#          ('27in 4K Gaming Monitor', 'Lightning Charging Cable'): 16,
#          ('Flatscreen TV', 'Macbook Pro Laptop'): 4,
#          ('Macbook Pro Laptop', 'Lightning Charging Cable'): 11,
#          ('AA Batteries (4-pack)', 'Google Phone'): 11,
#          ('Wired Headphones', '34in Ultrawide Monitor'): 17,
#          ('Google Phone', 'Vareebadd Phone'): 1,
#          ('ThinkPad Laptop', 'iPhone'): 3,
#          ('Vareebadd Phone', 'Flatscreen TV'): 3,
#          ('AAA Batteries (4-pack)', '20in Monitor'): 8,
#          ('Lightning Charging Cable', 'iPhone'): 9,
#          ('Macbook Pro Laptop', 'USB-C Charging Cable'): 12,
#          ('27in 4K Gaming Monitor', 'AAA Batteries (4-pack)'): 15,
#          ('Apple Airpods Headphones', 'iPhone'): 13,
#          ('Bose SoundSport Headphones', '20in Monitor'): 6,
#          ('27in FHD Monitor', '27in 4K Gaming Monitor'): 4,
#          ('AA Batteries (4-pack)', 'ThinkPad Laptop'): 9,
#          ('Wired Headphones', '27in FHD Monitor'): 12,
#          ('Bose SoundSport Headphones', 'iPhone'): 7,
#          ('20in Monitor', 'Wired Headphones'): 12,
#          ('AAA Batteries (4-pack)', 'ThinkPad Laptop'): 11,
#          ('ThinkPad Laptop', 'Apple Airpods Headphones'): 7,
#          ('Lightning Charging Cable', '34in Ultrawide Monitor'): 15,
#          ('34in Ultrawide Monitor', 'Flatscreen TV'): 3,
#          ('AAA Batteries (4-pack)', 'Apple Airpods Headphones'): 33,
#          ('20in Monitor', 'iPhone'): 1,
#          ('34in Ultrawide Monitor', 'Lightning Charging Cable'): 18,
#          ('Macbook Pro Laptop', 'LG Washing Machine'): 2,
#          ('ThinkPad Laptop', 'Flatscreen TV'): 4,
#          ('Bose SoundSport Headphones', 'Flatscreen TV'): 10,
#          ('34in Ultrawide Monitor', 'ThinkPad Laptop'): 3,
#          ('iPhone', 'AA Batteries (4-pack)'): 14,
#          ('Lightning Charging Cable', 'Flatscreen TV'): 12,
#          ('Flatscreen TV', 'iPhone'): 4,
#          ('27in 4K Gaming Monitor', 'ThinkPad Laptop'): 4,
#          ('Macbook Pro Laptop', 'Bose SoundSport Headphones'): 11,
#          ('iPhone', 'Flatscreen TV'): 6,
#          ('Wired Headphones', 'AAA Batteries (4-pack)'): 43,
#          ('Vareebadd Phone', 'Google Phone'): 4,
#          ('LG Dryer', 'Vareebadd Phone'): 1,
#          ('27in 4K Gaming Monitor', 'Wired Headphones'): 11,
#          ('Macbook Pro Laptop', 'Flatscreen TV'): 1,
#          ('Macbook Pro Laptop', 'iPhone'): 3,
#          ('Vareebadd Phone', 'iPhone'): 3,
#          ('Macbook Pro Laptop', 'Google Phone'): 4,
#          ('27in FHD Monitor', 'Apple Airpods Headphones'): 12,
#          ('Flatscreen TV', '34in Ultrawide Monitor'): 5,
#          ('Apple Airpods Headphones', '20in Monitor'): 6,
#          ('ThinkPad Laptop', 'Vareebadd Phone'): 1,
#          ('20in Monitor', '27in FHD Monitor'): 2,
#          ('Wired Headphones', '27in 4K Gaming Monitor'): 18,
#          ('Apple Airpods Headphones', 'Vareebadd Phone'): 6,
#          ('Bose SoundSport Headphones', 'Apple Airpods Headphones'): 18,
#          ('27in 4K Gaming Monitor', 'Google Phone'): 5,
#          ('USB-C Charging Cable', 'Google Phone'): 12,
#          ('Wired Headphones', 'LG Washing Machine'): 3,
#          ('Flatscreen TV', 'AAA Batteries (4-pack)'): 11,
#          ('Lightning Charging Cable', 'ThinkPad Laptop'): 9,
#          ('27in 4K Gaming Monitor', 'AA Batteries (4-pack)'): 12,
#          ('Google Phone', '34in Ultrawide Monitor'): 3,
#          ('Macbook Pro Laptop', '27in FHD Monitor'): 3,
#          ('Google Phone', 'Flatscreen TV'): 1,
#          ('Wired Headphones', 'Vareebadd Phone'): 6,
#          ('27in FHD Monitor', '34in Ultrawide Monitor'): 5,
#          ('34in Ultrawide Monitor', 'Apple Airpods Headphones'): 8,
#          ('34in Ultrawide Monitor', 'AAA Batteries (4-pack)'): 12,
#          ('Bose SoundSport Headphones', 'Vareebadd Phone'): 2,
#          ('27in 4K Gaming Monitor', '27in FHD Monitor'): 4,
#          ('Lightning Charging Cable', 'Macbook Pro Laptop'): 10,
#          ('Vareebadd Phone', 'ThinkPad Laptop'): 2,
#          ('Flatscreen TV', 'Apple Airpods Headphones'): 5,
#          ('34in Ultrawide Monitor', 'Bose SoundSport Headphones'): 6,
#          ('Wired Headphones', 'Macbook Pro Laptop'): 13,
#          ('Wired Headphones', 'Bose SoundSport Headphones'): 21,
#          ('20in Monitor', 'ThinkPad Laptop'): 2,
#          ('Google Phone', 'Apple Airpods Headphones'): 7,
#          ('Lightning Charging Cable', 'LG Washing Machine'): 4,
#          ('27in FHD Monitor', 'ThinkPad Laptop'): 4,
#          ('Bose SoundSport Headphones', '27in 4K Gaming Monitor'): 10,
#          ('Macbook Pro Laptop', '27in 4K Gaming Monitor'): 7,
#          ('LG Washing Machine', 'Google Phone'): 1,
#          ('LG Washing Machine', 'Wired Headphones'): 1,
#          ('Google Phone', 'iPhone'): 6,
#          ('Flatscreen TV', 'Bose SoundSport Headphones'): 3,
#          ('AA Batteries (4-pack)', 'Vareebadd Phone'): 3,
#          ('Lightning Charging Cable', 'Lightning Charging Cable'): 6,
#          ('27in FHD Monitor', 'Macbook Pro Laptop'): 6,
#          ('ThinkPad Laptop', 'Wired Headphones'): 4,
#          ('27in FHD Monitor', 'LG Dryer'): 2,
#          ('27in FHD Monitor', '20in Monitor'): 3,
#          ('20in Monitor', 'AA Batteries (4-pack)'): 6,
#          ('iPhone', 'Google Phone'): 3,
#          ('Vareebadd Phone', '27in 4K Gaming Monitor'): 2,
#          ('iPhone', 'ThinkPad Laptop'): 4,
#          ('27in 4K Gaming Monitor', '20in Monitor'): 2,
#          ('LG Washing Machine', 'Lightning Charging Cable'): 2,
#          ('Bose SoundSport Headphones', 'Google Phone'): 8,
#          ('Bose SoundSport Headphones', 'Macbook Pro Laptop'): 4,
#          ('LG Dryer', 'Flatscreen TV'): 1,
#          ('27in 4K Gaming Monitor', 'iPhone'): 3,
#          ('LG Washing Machine', 'Bose SoundSport Headphones'): 2,
#          ('AA Batteries (4-pack)', 'LG Dryer'): 2,
#          ('Vareebadd Phone', 'AAA Batteries (4-pack)'): 2,
#          ('Flatscreen TV', 'Google Phone'): 3,
#          ('iPhone', '20in Monitor'): 2,
#          ('27in FHD Monitor', 'LG Washing Machine'): 1,
#          ('LG Dryer', '27in FHD Monitor'): 1,
#          ('34in Ultrawide Monitor', '27in FHD Monitor'): 5,
#          ('20in Monitor', '34in Ultrawide Monitor'): 1,
#          ('USB-C Charging Cable', 'USB-C Charging Cable'): 4,
#          ('Google Phone', 'Macbook Pro Laptop'): 3,
#          ('AAA Batteries (4-pack)', 'Vareebadd Phone'): 4,
#          ('34in Ultrawide Monitor', '20in Monitor'): 1,
#          ('20in Monitor', 'Google Phone'): 2,
#          ('LG Washing Machine', 'AAA Batteries (4-pack)'): 4,
#          ('34in Ultrawide Monitor', 'LG Washing Machine'): 1,
#          ('Google Phone', '27in 4K Gaming Monitor'): 1,
#          ('LG Washing Machine', 'iPhone'): 1,
#          ('LG Dryer', 'Wired Headphones'): 1,
#          ('27in FHD Monitor', 'Vareebadd Phone'): 1,
#          ('LG Washing Machine', '27in 4K Gaming Monitor'): 1,
#          ('Flatscreen TV', 'ThinkPad Laptop'): 2,
#          ('27in 4K Gaming Monitor', 'Flatscreen TV'): 3,
#          ('LG Washing Machine', 'Apple Airpods Headphones'): 1,
#          ('27in 4K Gaming Monitor', 'LG Dryer'): 1,
#          ('20in Monitor', 'LG Washing Machine'): 1,
#          ('Apple Airpods Headphones', 'LG Dryer'): 3,
#          ('LG Dryer', 'Google Phone'): 1,
#          ('20in Monitor', 'AAA Batteries (4-pack)'): 3,
#          ('Vareebadd Phone', '27in FHD Monitor'): 1,
#          ('ThinkPad Laptop', '27in 4K Gaming Monitor'): 1,
#          ('ThinkPad Laptop', '27in FHD Monitor'): 2,
#          ('20in Monitor', 'Flatscreen TV'): 1,
#          ('USB-C Charging Cable', 'LG Dryer'): 1,
#          ('Wired Headphones', 'Wired Headphones'): 2,
#          ('LG Washing Machine', '20in Monitor'): 1,
#          ('Flatscreen TV', '20in Monitor'): 1,
#          ('27in FHD Monitor', 'Flatscreen TV'): 2,
#          ('27in FHD Monitor', 'Google Phone'): 1,
#          ('iPhone', '27in FHD Monitor'): 1,
#          ('LG Dryer', 'AAA Batteries (4-pack)'): 1,
#          ('ThinkPad Laptop', '34in Ultrawide Monitor'): 1,
#          ('iPhone', 'LG Washing Machine'): 1,
#          ('iPhone', 'Macbook Pro Laptop'): 3,
#          ('Google Phone', '20in Monitor'): 2,
#          ('AAA Batteries (4-pack)', 'LG Dryer'): 1,
#          ('LG Dryer', '27in 4K Gaming Monitor'): 1,
#          ('LG Dryer', 'Lightning Charging Cable'): 1,
#          ('ThinkPad Laptop', 'LG Dryer'): 1,
#          ('LG Washing Machine', 'AA Batteries (4-pack)'): 1})

# %%
top10_combos=cnt.most_common(10) #extracted top 10 combos
top10_combos    #single list returned
# Out:
# [(('iPhone', 'Lightning Charging Cable'), 1001),
#  (('Google Phone', 'USB-C Charging Cable'), 985),
#  (('iPhone', 'Wired Headphones'), 447),
#  (('Google Phone', 'Wired Headphones'), 413),
#  (('Vareebadd Phone', 'USB-C Charging Cable'), 361),
#  (('iPhone', 'Apple Airpods Headphones'), 359),
#  (('Google Phone', 'Bose SoundSport Headphones'), 220),
#  (('USB-C Charging Cable', 'Wired Headphones'), 159),
#  (('Vareebadd Phone', 'Wired Headphones'), 143),
#  (('Lightning Charging Cable', 'Wired Headphones'), 92)]

# %%
Top_Combos=pd.DataFrame(top10_combos,columns=['combos','Frequency'])  #created 2 columns and converted into dataframe
Top_Combos
# Out:
#                                          combos  Frequency
# 0            (iPhone, Lightning Charging Cable)       1001
# 1          (Google Phone, USB-C Charging Cable)        985
# 2                    (iPhone, Wired Headphones)        447
# 3              (Google Phone, Wired Headphones)        413
# 4       (Vareebadd Phone, USB-C Charging Cable)        361
# 5            (iPhone, Apple Airpods Headphones)        359
# 6    (Google Phone, Bose SoundSport Headphones)        220
# 7      (USB-C Charging Cable, Wired Headphones)        159
# 8           (Vareebadd Phone, Wired Headphones)        143
# 9  (Lightning Charging Cable, Wired Headphones)         92

# %%
Top_Combos['combos']=Top_Combos['combos'].apply(lambda x:str(x))

#cobmos column is tupple dtype/object not a string ,conerted into string

Top_Combos['combos']=Top_Combos['combos'].apply(lambda x:x.replace('(','').replace(')', '').replace("'", '')) 

#replaced brackets '(' &')' and ' with blank

Top_Combos_sorted=Top_Combos.sort_values(by='Frequency').reset_index(drop=True) 

#sorted in ascending

Top_Combos_sorted
# Out:
#                                        combos  Frequency
# 0  Lightning Charging Cable, Wired Headphones         92
# 1           Vareebadd Phone, Wired Headphones        143
# 2      USB-C Charging Cable, Wired Headphones        159
# 3    Google Phone, Bose SoundSport Headphones        220
# 4            iPhone, Apple Airpods Headphones        359
# 5       Vareebadd Phone, USB-C Charging Cable        361
# 6              Google Phone, Wired Headphones        413
# 7                    iPhone, Wired Headphones        447
# 8          Google Phone, USB-C Charging Cable        985
# 9            iPhone, Lightning Charging Cable       1001

# %%
plt.figure()
plt.barh(Top_Combos_sorted['combos'],Top_Combos_sorted['Frequency'].sort_values(ascending=True),color='#4dc592')
plt.xlabel('Frequency')
plt.ylabel('Product_Combinations')
plt.show()

# %% [markdown]
# ###  Question 6: Which product sold the most?

# %%
Best_product=data.groupby('Product')['Quantity Ordered'].sum().reset_index()

# %%
plt.barh(Best_product['Product'],Best_product['Quantity Ordered'],color='#374b3e')
plt.xlabel('Quantity')
plt.ylabel('Product_Combinations')
# p2.set_xticklabels(price['Product'],rotation=90)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### why those products sold the most?

# %%
price=data.pivot_table(index='Product',values='Price Each').reset_index()
price
# Out:
#                        Product  Price Each
# 0                 20in Monitor      109.99
# 1       27in 4K Gaming Monitor      389.99
# 2             27in FHD Monitor      149.99
# 3       34in Ultrawide Monitor      379.99
# 4        AA Batteries (4-pack)        3.84
# 5       AAA Batteries (4-pack)        2.99
# 6     Apple Airpods Headphones      150.00
# 7   Bose SoundSport Headphones       99.99
# 8                Flatscreen TV      300.00
# 9                 Google Phone      600.00
# 10                    LG Dryer      600.00
# 11          LG Washing Machine      600.00
# 12    Lightning Charging Cable       14.95
# 13          Macbook Pro Laptop     1700.00
# 14             ThinkPad Laptop      999.99
# 15        USB-C Charging Cable       11.95
# 16             Vareebadd Phone      400.00
# 17            Wired Headphones       11.99
# 18                      iPhone      700.00

# %%
plt.bar(Best_product['Product'],Best_product['Quantity Ordered'],color='g')
plt.ylabel('Quantity')
plt.xlabel('Product_Combinations')
plt.xticks(rotation=90)

p2=plt.twinx()
plt.plot(price['Product'],price['Price Each'],color='#374b3e',linewidth=1,marker='d',markersize=4)
p2.set_ylabel('Average Price')

plt.show()
